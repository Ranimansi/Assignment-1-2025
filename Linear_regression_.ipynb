# %% [markdown]
# <a href="https://colab.research.google.com/github/Ranimansi/Assignment-1-2025/blob/main/Linear_regression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
country_wise_latest=pd.read_csv('country_wise_latest.csv')

# %%
country_wise_latest.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
country_wise_latest[country_wise_latest['Deaths']>1000]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 0           Afghanistan      36263    1269      25198     9796        106
# 2               Algeria      27973    1163      18837     7973        616
# 6             Argentina     167416    3059      72575    91782       4890
# 13           Bangladesh     226225    2965     125683    97577       2772
# 16              Belgium      66428    9822      17452    39154        402
# 20              Bolivia      71181    2647      21478    47056       1752
# 23               Brazil    2442375   87618    1846641   508116      23284
# 32               Canada     116458    8944          0   107514        682
# 35                Chile     347923    9187     319954    18782       2133
# 36                China      86783    4656      78869     3258        213
# 37             Colombia     257101    8777     131161   117163      16306
# 50   Dominican Republic      64156    1083      30204    32869       1248
# ...

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='Deaths',y='Recovered',data=country_wise_latest,hue='WHO Region')
plt.show()

# %%
y=country_wise_latest[['Deaths']]

# %%
x=country_wise_latest[['Recovered']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#      Recovered
# 103       6260
# 185       2815
# 172     210469
# 56        1923
# 54         842

# %%
x_test.head()
# Out:
#      Recovered
# 49          18
# 165       6028
# 140         15
# 19          86
# 109       4653

# %%
y_train.head()
# Out:
#      Deaths
# 103      91
# 185     140
# 172    5630
# 56       69
# 54       51

# %%
y_test.head()
# Out:
#      Deaths
# 49        0
# 165      60
# 140       0
# 19        0
# 109     156

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#      Deaths
# 49        0
# 165      60
# 140       0
# 19        0
# 109     156

# %%
y_pred[0:5]
# Out:
# array([[-824.36197639],
#        [-280.94876916],
#        [-824.6332309 ],
#        [-818.21354077],
#        [-405.27375418]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-237cd1566df1> in <module>
# ----> 1 mean_squared_error(y_test,y_pred)
#
# NameError: name 'y_test' is not defined
